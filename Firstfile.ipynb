# %% [markdown]
# <a href="https://colab.research.google.com/github/shasi4069/AmountCalculator.java/blob/main/Firstfile.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#to find  out oput hcf
#input two number
num1=int(input("Enter first number:"))
num2=int(input("Enter second number:"))
#-----------------------------------------
if(num2==0):
  print("HCF :",num1)
else:
    while(num2!=0):
      rem=num1%num2
      num1=num2
      num2=rem
      #-------------------------
      print("HCF :",num1)
# Out:
# Enter first number:34
# Enter second number:12
# HCF : 12
# HCF : 10
# HCF : 2

# %%
# find out greatest digit present in given number
# input : 3723
#output: greatest digit - 7
